# %% [markdown]
# <a href="https://colab.research.google.com/github/viknesh20-20/Data-Science-Tasks/blob/main/Task_3_TableExtracter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tabula
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tabula: filename=tabula-1.0.5-py3-none-any.whl size=10587 sha256=03d374e7986022bcb6e08afb630ecb459b58e2c864f65c915be4b6aa49977d87
#   Stored in directory: /root/.cache/pip/wheels/3c/5d/6a/bd13fe26e73e2170dfea1f6ccb69a69e824735e04b73192b39
# Successfully built tabula
# ...

# %%
pip install tabula-py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 49.3 MB/s eta 0:00:00
# ...

# %%
import tabula as tb
import pandas as pd
import os

# %%
import PyPDF2
import pandas as pd

def extract_tables_from_pdf(pdf_path):
    # Open the PDF file
    with open(pdf_path, 'rb') as file:
        pdf_reader = PyPDF2.PdfReader(file)

        # Iterate through each page
        tables = []
        for page_num in range(len(pdf_reader.pages)):
            page = pdf_reader.pages[page_num]

            # Extract text from the page
            text = page.extract_text()

            # Split the text into lines and assume each line is a row in the table
            rows = [line.split() for line in text.split('\n') if line.strip()]

            # Convert the rows into a DataFrame
            table = pd.DataFrame(rows)
            tables.append(table)

    return tables

# Example usage:
pdf_path = '/content/drive/MyDrive/Test-Int-Package-Data.pdf'
tables = extract_tables_from_pdf(pdf_path)

# Save tables to Excel
with pd.ExcelWriter('/content/drive/MyDrive/output.xlsx') as writer:
    for i, table in enumerate(tables):
        table.to_excel(writer)

# %%
file1 = "/content/drive/MyDrive/Test-Int-Package-Data.pdf"
table = tb.read_pdf(file1,pages=1)

folder_name = "/content/drive/MyDrive"
if not os.path.isdir(folder_name):
    os.mkdir(folder_name)
for i, table in enumerate(table, start=1):
    table.to_excel(os.path.join(folder_name, f"table_{i}.xlsx"), index=False)
# Out:
# WARNING:tabula.backend:Error importing jpype dependencies. Fallback to subprocess.
# WARNING:tabula.backend:No module named 'jpype'

# %%
df = pd.read_excel("/content/drive/MyDrive/table_1.xlsx")
df.head()
# Out:
#              Hotel ID          Type  Location Destination            Property  \
# 0  I-BAL-UBUD-AKS-001  International     Bali        Ubud  Aksari Resort Ubud
# 1  I-BAL-UBUD-AKS-001  International     Bali        Ubud  Aksari Resort Ubud
# 2  I-BAL-UBUD-AKS-001  International     Bali        Ubud  Aksari Resort Ubud
# 3  I-BAL-UBUD-AKS-001  International     Bali        Ubud  Aksari Resort Ubud
# 4  I-BAL-UBUD-AKS-001  International     Bali        Ubud  Aksari Resort Ubud
#
#                                        Room Category  CUR  Totel Rooms  \
# 0  Royal One Bedroom River View Villa with Privat...  IDR          2.0
# 1          Royal One Bedroom Villa with Private Pool  IDR          4.0
# 2                One Bedroom Villa with Private Pool  IDR          1.0
# 3          Royal Two Bedroom Villa with Private Pool  IDR          1.0
# 4                                       Aksari Suite  IDR          8.0
#
#         CP 2N \nHONEYMOON PACKAGE IDR  1N-INR Price  \
# ...

# %%
pd.set_option("display.max_columns",None)

# %%
df
# Out:
#               Hotel ID          Type  Location Destination  \
# 0   I-BAL-UBUD-AKS-001  International     Bali        Ubud
# 1   I-BAL-UBUD-AKS-001  International     Bali        Ubud
# 2   I-BAL-UBUD-AKS-001  International     Bali        Ubud
# 3   I-BAL-UBUD-AKS-001  International     Bali        Ubud
# 4   I-BAL-UBUD-AKS-001  International     Bali        Ubud
# 5   I-BAL-UBUD-AKS-001  International     Bali        Ubud
# 6   I-BAL-UBUD-AKS-001  International     Bali        Ubud
# 7   I-BAL-UBUD-KAA-002  International     Bali        Ubud
# 8   I-BAL-UBUD-KAA-002  International     Bali        Ubud
# 9   I-BAL-UBUD-KAA-002  International     Bali        Ubud
# 10  I-BAL-UBUD-KAA-002  International     Bali        Ubud
# 11  I-BAL-UBUD-ASV-003  International     Bali        Ubud
# 12  I-BAL-UBUD-ASV-003  International     Bali        Ubud
# 13  I-BAL-UBUD-ASV-003  International     Bali        Ubud
# 14  I-BAL-UBUD-DED-004  International     Bali        Ubud
# ...

# %%
new_df = df[["Hotel ID","Location","Destination","Property","Room Category","2N \nHONEYMOON PACKAGE IDR","1N-INR Price","Package-ID-1","SN-01"]].copy()
new_df
# Out:
#               Hotel ID Location Destination                    Property  \
# 0   I-BAL-UBUD-AKS-001     Bali        Ubud          Aksari Resort Ubud
# 1   I-BAL-UBUD-AKS-001     Bali        Ubud          Aksari Resort Ubud
# 2   I-BAL-UBUD-AKS-001     Bali        Ubud          Aksari Resort Ubud
# 3   I-BAL-UBUD-AKS-001     Bali        Ubud          Aksari Resort Ubud
# 4   I-BAL-UBUD-AKS-001     Bali        Ubud          Aksari Resort Ubud
# 5   I-BAL-UBUD-AKS-001     Bali        Ubud          Aksari Resort Ubud
# 6   I-BAL-UBUD-AKS-001     Bali        Ubud          Aksari Resort Ubud
# 7   I-BAL-UBUD-KAA-002     Bali        Ubud         Kaamala Resort Ubud
# 8   I-BAL-UBUD-KAA-002     Bali        Ubud         Kaamala Resort Ubud
# 9   I-BAL-UBUD-KAA-002     Bali        Ubud         Kaamala Resort Ubud
# 10  I-BAL-UBUD-KAA-002     Bali        Ubud         Kaamala Resort Ubud
# 11  I-BAL-UBUD-ASV-003     Bali        Ubud           Asvara Villa Ubud
# ...
