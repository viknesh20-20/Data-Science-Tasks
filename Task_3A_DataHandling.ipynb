# %% [markdown]
# <a href="https://colab.research.google.com/github/viknesh20-20/Data-Science-Tasks/blob/main/Task_3A_DataHandling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import csv
df = pd.read_excel("/content/drive/MyDrive/table_1.xlsx")
print(df)
# Out:
#               Hotel ID          Type  Location Destination  \
# 0   I-BAL-UBUD-AKS-001  International     Bali        Ubud
# 1   I-BAL-UBUD-AKS-001  International     Bali        Ubud
# 2   I-BAL-UBUD-AKS-001  International     Bali        Ubud
# 3   I-BAL-UBUD-AKS-001  International     Bali        Ubud
# 4   I-BAL-UBUD-AKS-001  International     Bali        Ubud
# 5   I-BAL-UBUD-AKS-001  International     Bali        Ubud
# 6   I-BAL-UBUD-AKS-001  International     Bali        Ubud
# 7   I-BAL-UBUD-KAA-002  International     Bali        Ubud
# 8   I-BAL-UBUD-KAA-002  International     Bali        Ubud
# 9   I-BAL-UBUD-KAA-002  International     Bali        Ubud
# 10  I-BAL-UBUD-KAA-002  International     Bali        Ubud
# 11  I-BAL-UBUD-ASV-003  International     Bali        Ubud
# 12  I-BAL-UBUD-ASV-003  International     Bali        Ubud
# 13  I-BAL-UBUD-ASV-003  International     Bali        Ubud
# 14  I-BAL-UBUD-DED-004  International     Bali        Ubud
# ...

# %%
df.head()
# Out:
#              Hotel ID          Type  Location Destination            Property  \
# 0  I-BAL-UBUD-AKS-001  International     Bali        Ubud  Aksari Resort Ubud
# 1  I-BAL-UBUD-AKS-001  International     Bali        Ubud  Aksari Resort Ubud
# 2  I-BAL-UBUD-AKS-001  International     Bali        Ubud  Aksari Resort Ubud
# 3  I-BAL-UBUD-AKS-001  International     Bali        Ubud  Aksari Resort Ubud
# 4  I-BAL-UBUD-AKS-001  International     Bali        Ubud  Aksari Resort Ubud
#
#                                        Room Category  CUR  Totel Rooms  \
# 0  Royal One Bedroom River View Villa with Privat...  IDR          2.0
# 1          Royal One Bedroom Villa with Private Pool  IDR          4.0
# 2                One Bedroom Villa with Private Pool  IDR          1.0
# 3          Royal Two Bedroom Villa with Private Pool  IDR          1.0
# 4                                       Aksari Suite  IDR          8.0
#
#         CP 2N \nHONEYMOON PACKAGE IDR  1N-INR Price  \
# ...

# %%
pd.set_option("display.max_columns",None)
df.head()
# Out:
#              Hotel ID          Type  Location Destination            Property  \
# 0  I-BAL-UBUD-AKS-001  International     Bali        Ubud  Aksari Resort Ubud
# 1  I-BAL-UBUD-AKS-001  International     Bali        Ubud  Aksari Resort Ubud
# 2  I-BAL-UBUD-AKS-001  International     Bali        Ubud  Aksari Resort Ubud
# 3  I-BAL-UBUD-AKS-001  International     Bali        Ubud  Aksari Resort Ubud
# 4  I-BAL-UBUD-AKS-001  International     Bali        Ubud  Aksari Resort Ubud
#
#                                        Room Category  CUR  Totel Rooms  \
# 0  Royal One Bedroom River View Villa with Privat...  IDR          2.0
# 1          Royal One Bedroom Villa with Private Pool  IDR          4.0
# 2                One Bedroom Villa with Private Pool  IDR          1.0
# 3          Royal Two Bedroom Villa with Private Pool  IDR          1.0
# 4                                       Aksari Suite  IDR          8.0
#
#         CP 2N \nHONEYMOON PACKAGE IDR  1N-INR Price  \
# ...

# %%
new_df = df[["Package-ID-1","Hotel ID","Location","Destination","Property","Room Category","2N \nHONEYMOON PACKAGE IDR","1N-INR Price","SN-01"]].copy()
new_df
# Out:
#        Package-ID-1            Hotel ID Location Destination  \
# 0   BA-HO-12-NO-002  I-BAL-UBUD-AKS-001     Bali        Ubud
# 1   BA-HO-12-NO-003  I-BAL-UBUD-AKS-001     Bali        Ubud
# 2   BA-HO-12-NO-004  I-BAL-UBUD-AKS-001     Bali        Ubud
# 3   BA-HO-12-NO-005  I-BAL-UBUD-AKS-001     Bali        Ubud
# 4   BA-HO-12-NO-006  I-BAL-UBUD-AKS-001     Bali        Ubud
# 5   BA-HO-12-NO-007  I-BAL-UBUD-AKS-001     Bali        Ubud
# 6   BA-HO-12-NO-008  I-BAL-UBUD-AKS-001     Bali        Ubud
# 7   BA-HO-12-NO-002  I-BAL-UBUD-KAA-002     Bali        Ubud
# 8   BA-HO-12-NO-009  I-BAL-UBUD-KAA-002     Bali        Ubud
# 9   BA-HO-12-NO-010  I-BAL-UBUD-KAA-002     Bali        Ubud
# 10  BA-HO-12-NO-011  I-BAL-UBUD-KAA-002     Bali        Ubud
# 11  BA-HO-12-NO-001  I-BAL-UBUD-ASV-003     Bali        Ubud
# 12  BA-HO-12-NO-012  I-BAL-UBUD-ASV-003     Bali        Ubud
# 13  BA-HO-12-NO-007  I-BAL-UBUD-ASV-003     Bali        Ubud
# ...

# %%
new_df.head()
# Out:
#       Package-ID-1            Hotel ID Location Destination  \
# 0  BA-HO-12-NO-002  I-BAL-UBUD-AKS-001     Bali        Ubud
# 1  BA-HO-12-NO-003  I-BAL-UBUD-AKS-001     Bali        Ubud
# 2  BA-HO-12-NO-004  I-BAL-UBUD-AKS-001     Bali        Ubud
# 3  BA-HO-12-NO-005  I-BAL-UBUD-AKS-001     Bali        Ubud
# 4  BA-HO-12-NO-006  I-BAL-UBUD-AKS-001     Bali        Ubud
#
#              Property                                      Room Category  \
# 0  Aksari Resort Ubud  Royal One Bedroom River View Villa with Privat...
# 1  Aksari Resort Ubud          Royal One Bedroom Villa with Private Pool
# 2  Aksari Resort Ubud                One Bedroom Villa with Private Pool
# 3  Aksari Resort Ubud          Royal Two Bedroom Villa with Private Pool
# 4  Aksari Resort Ubud                                       Aksari Suite
#
#   2N \nHONEYMOON PACKAGE IDR  1N-INR Price  SN-01
# 0                   11800000   17067.50720      2
# 1                   10800000   17067.56054      3
# ...

# %%
ar = np.asarray(df["Package-ID-1"].drop_duplicates())
ar.sort()
print(ar)
# Out:
# ['BA-HO-12-NO-001' 'BA-HO-12-NO-002' 'BA-HO-12-NO-003' 'BA-HO-12-NO-004'
#  'BA-HO-12-NO-005' 'BA-HO-12-NO-006' 'BA-HO-12-NO-007' 'BA-HO-12-NO-008'
#  'BA-HO-12-NO-009' 'BA-HO-12-NO-010' 'BA-HO-12-NO-011' 'BA-HO-12-NO-012'
#  'BA-HO-12-NO-013' 'BA-HO-12-NO-014' 'BA-HO-12-NO-015' 'BA-HO-12-NO-016']

# %%
i=0
while(i<16):
  print(new_df.loc[new_df["Package-ID-1"]==ar[i]])
  print(new_df["Package-ID-1"]==ar[i])
  i+=1
# Out:
#        Package-ID-1            Hotel ID Location Destination  \
# 11  BA-HO-12-NO-001  I-BAL-UBUD-ASV-003     Bali        Ubud
# 40  BA-HO-12-NO-001  I-BAL-KUTA-RAM-015     Bali        Kuta
#
#                       Property  \
# 11           Asvara Villa Ubud
# 40  Rama Beach Resort & Villas
#
#                                         Room Category  \
# 11  Royal One Bedroom Villa with Private Pool and ...
# 40                                             Deluxe
#
#    2N \nHONEYMOON PACKAGE IDR  1N-INR Price  SN-01
# 11                    5400000    17068.0939      2
# 40                        NaN     5066.9162      3
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# ...

# %%
ex_df= new_df.loc[df["Package-ID-1"]==ar[2]]
sr = pd.Series(dtype="object")
for _,i in ex_df.iterrows():
    sr = pd.concat([sr,i],axis=1)
sr.to_excel("/content/drive/MyDrive/table_2.xlsx",index=False)

# %%
dfff = pd.read_excel("/content/drive/MyDrive/table_2.xlsx")
dfff = dfff.drop(0,axis=1).transpose().to_numpy()

temp = dfff.ravel()
temp =temp.tolist()
temp
# Out:
# ['BA-HO-12-NO-003',
#  'I-BAL-UBUD-AKS-001',
#  'Bali',
#  'Ubud',
#  'Aksari Resort Ubud',
#  'Royal One Bedroom Villa with Private Pool',
#  10800000,
#  17067.56054,
#  3,
#  'BA-HO-12-NO-003',
#  'I-BAL-UBUD-DED-004',
#  'Bali',
#  'Ubud',
#  'Dedary Resort Ubud',
#  'Two Bedroom Villa with Private Pool and Bathtub',
#  'Not Available',
#  17068.41391,
#  2,
#  'BA-HO-12-NO-003',
#  'I-BAL-UBUD-AMA-005',
#  'Bali',
#  'Ubud',
#  'Amarea Resort Ubud',
#  'Ubud Room',
#  'Not Available',
#  17068.52058,
#  3,
#  'BA-HO-12-NO-003',
#  'I-BAL-SEMI-AKS-009',
#  'Bali',
#  'Seminyak',
#  'Aksari Seminyak',
#  'One Bedroom Villa with Private Pool and Bathtub',
#  5700000,
#  17069.26729,
#  3]

# %%
new_df[:0]
# Out:
# Empty DataFrame
# Columns: [Package-ID-1, Hotel ID, Location, Destination, Property, Room Category, 2N
# HONEYMOON PACKAGE IDR, 1N-INR Price, SN-01]
# Index: []

# %%
new_df.grou

# %%
with open ("/content/drive/MyDrive/table_2.csv", 'w') as csv_file:
    csv_writer = csv.writer(csv_file)
    new_df[:0].to_csv('/content/drive/MyDrive/table_2.csv', mode='a', index=False, header=False)
    #for i in range(len(ar)):
        #if df["Package-ID-1"]==ar[i]:
          #print(new_df.loc[df["Package-ID-1"]==ar[i]])
          #print(new_df.loc[df["Package-ID-1"]==ar[i+1]])
    a = df["Package-ID-1"]==ar[0]
    type(a)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40     True
# Name: Package-ID-1, dtype: bool

# %%
dff = pd.read_csv("/content/drive/MyDrive/table_2.csv")

# %%
df1.head()
# Out:
#    I-BAL-UBUD-ASV-003  Bali  Ubud           Asvara Villa Ubud  \
# 0  I-BAL-KUTA-RAM-015  Bali  Kuta  Rama Beach Resort & Villas
# 1  I-BAL-UBUD-AKS-001  Bali  Ubud          Aksari Resort Ubud
# 2  I-BAL-UBUD-KAA-002  Bali  Ubud         Kaamala Resort Ubud
# 3  I-BAL-UBUD-AKS-001  Bali  Ubud          Aksari Resort Ubud
# 4  I-BAL-UBUD-DED-004  Bali  Ubud          Dedary Resort Ubud
#
#   Royal One Bedroom Villa with Private Pool and Jacuzzi        5400000  \
# 0                                             Deluxe               NaN
# 1  Royal One Bedroom River View Villa with Privat...          11800000
# 2  Royal One Bedroom Ricefield View Villa with Pr...           8800000
# 3          Royal One Bedroom Villa with Private Pool          10800000
# 4    Two Bedroom Villa with Private Pool and Bathtub     Not Available
#
#     17068.0939  BA-HO-12-NO-001  2
# 0    5066.9162  BA-HO-12-NO-001  3
# 1   17067.5072  BA-HO-12-NO-002  2
# 2  17067.88055  BA-HO-12-NO-002  2
# ...

# %%
import pandas as pd
input_file = '/content/drive/MyDrive/table_1.xlsx'
df = pd.read_excel(input_file)


package_hotels = {}

for _, row in df.iterrows():
    package_id = row['Package-ID-1']
    print(package_id)
    hotel_info = {
        'hotel id': row['Hotel ID'],
        'no of nights': row['SN-01'],
        'hotel name': row['Property'],
        'room category': row['Room Category'],
        'price per night': row['1N-INR Price']
    }

    if package_id in package_hotels:
        package_hotels[package_id].append(hotel_info)
    else:
        package_hotels[package_id] = [hotel_info]

unique_packages_data = []

for package_id, hotels in package_hotels.items():
    package_data = {
        'package id': package_id,
        'location': df.loc[df['Package-ID-1'] == package_id, 'Location'].values[0],
        'destination': df.loc[df['Package-ID-1'] == package_id, 'Destination'].values[0],
        'theme': "Honeymoon",
    }

    for i, hotel_info in enumerate(hotels, start=1):
        package_data.update({
            f'hotel id {i}': hotel_info['hotel id'],
            f'no of nights {i}': hotel_info['no of nights'],
            f'hotel name {i}': hotel_info['hotel name'],
            f'room category {i}': hotel_info['room category'],
            f'price per night {i}': hotel_info['price per night']
        })

    unique_packages_data.append(package_data)

unique_packages_df = pd.DataFrame(unique_packages_data)


output_file = '/content/drive/MyDrive/table_2.xlsx'
unique_packages_df.to_excel(output_file, index=False)

print(f"Unique package IDs with associated hotel details have been saved to '{output_file}'")
# Out:
# BA-HO-12-NO-002
# BA-HO-12-NO-003
# BA-HO-12-NO-004
# BA-HO-12-NO-005
# BA-HO-12-NO-006
# BA-HO-12-NO-007
# BA-HO-12-NO-008
# BA-HO-12-NO-002
# BA-HO-12-NO-009
# BA-HO-12-NO-010
# BA-HO-12-NO-011
# BA-HO-12-NO-001
# BA-HO-12-NO-012
# BA-HO-12-NO-007
# BA-HO-12-NO-009
# BA-HO-12-NO-008
# BA-HO-12-NO-004
# BA-HO-12-NO-003
# BA-HO-12-NO-005
# BA-HO-12-NO-003
# BA-HO-12-NO-006
# BA-HO-12-NO-010
# BA-HO-12-NO-012
# BA-HO-12-NO-013
# BA-HO-12-NO-014
# BA-HO-12-NO-015
# BA-HO-12-NO-016
# BA-HO-12-NO-011
# BA-HO-12-NO-014
# BA-HO-12-NO-013
# BA-HO-12-NO-010
# BA-HO-12-NO-011
# BA-HO-12-NO-012
# BA-HO-12-NO-003
# BA-HO-12-NO-004
# BA-HO-12-NO-004
# BA-HO-12-NO-013
# BA-HO-12-NO-014
# BA-HO-12-NO-015
# BA-HO-12-NO-016
# BA-HO-12-NO-001
# Unique package IDs with associated hotel details have been saved to '/content/drive/MyDrive/table_2.xlsx'
